# %% [markdown]
# #1. EDA - Exploratory Data Analysis
#
# Dataset source: https://www.kaggle.com/datasets/fedesoriano/company-bankruptcy-prediction
#
# ### Context
#
# The data were collected from the Taiwan Economic Journal for the years 1999 to 2009. Company bankruptcy was defined based on the business regulations of the Taiwan Stock Exchange.
#
# ### Source
#
# Deron Liang and Chih-Fong Tsai, deronliang '@' gmail.com; cftsai '@' mgt.ncu.edu.tw, National Central University, Taiwan
# The data was obtained from UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Taiwanese+Bankruptcy+Prediction
#
# ### Data
#
# In the dataframe we can find the 96 columns - 1 targe column and 95 factors and 6819 rows:
#
# | Column | Description |
# | ------ | ----------- |
# | Y | Bankrupt?: Class label |
# | X1 | ROA(C) before interest and depreciation before interest: Return On Total Assets(C)|
# | X2 | ROA(A) before interest and % after tax: Return On Total Assets(A)
# | X3 | ROA(B) before interest and depreciation after tax: Return On Total Assets(B)
# | X4 | Operating Gross Margin: Gross Profit/Net Sales
# | X5 | Realized Sales Gross Margin: Realized Gross Profit/Net Sales
# | X6 | Operating Profit Rate: Operating Income/Net Sales
# | X7 | Pre-tax net Interest Rate: Pre-Tax Income/Net Sales
# | X8 | After-tax net Interest Rate: Net Income/Net Sales
# | X9 | Non-industry income and expenditure/revenue: Net Non-operating Income Ratio
# | X10 | Continuous interest rate (after tax): Net Income-Exclude Disposal Gain or Loss/Net Sales
# | X11 | Operating Expense Rate: Operating Expenses/Net Sales
# | X12 | Research and development expense rate: (Research and Development Expenses)/Net Sales
# | X13 | Cash flow rate: Cash Flow from Operating/Current Liabilities
# | X14 | Interest-bearing debt interest rate: Interest-bearing Debt/Equity
# | X15 | Tax rate (A): Effective Tax Rate
# | X16 | Net Value Per Share (B): Book Value Per Share(B)
# | X17 | Net Value Per Share (A): Book Value Per Share(A)
# | X18 | Net Value Per Share (C): Book Value Per Share(C)
# | X19 | Persistent EPS in the Last Four Seasons: EPS-Net Income
# | X20 | Cash Flow Per Share
# | X21 | Revenue Per Share (Yuan ¥): Sales Per Share
# | X22 | Operating Profit Per Share (Yuan ¥): Operating Income Per Share
# | X23 | Per Share Net profit before tax (Yuan ¥): Pretax Income Per Share
# | X24 | Realized Sales Gross Profit Growth Rate
# | X25 | Operating Profit Growth Rate: Operating Income Growth
# | X26 | After-tax Net Profit Growth Rate: Net Income Growth
# | X27 | Regular Net Profit Growth Rate: Continuing Operating Income after Tax Growth
# | X28 | Continuous Net Profit Growth Rate: Net Income-Excluding Disposal Gain or Loss Growth
# | X29 | Total Asset Growth Rate: Total Asset Growth
# | X30 | Net Value Growth Rate: Total Equity Growth
# | X31 | Total Asset Return Growth Rate Ratio: Return on Total Asset Growth
# | X32 | Cash Reinvestment %: Cash Reinvestment Ratio
# | X33 | Current Ratio
# | X34 | Quick Ratio: Acid Test
# | X35 | Interest Expense Ratio: Interest Expenses/Total Revenue
# | X36 | Total debt/Total net worth: Total Liability/Equity Ratio
# | X37 | Debt ratio %: Liability/Total Assets
# | X38 | Net worth/Assets: Equity/Total Assets
# | X39 | Long-term fund suitability ratio (A): (Long-term Liability+Equity)/Fixed Assets
# | X40 | Borrowing dependency: Cost of Interest-bearing Debt
# | X41 | Contingent liabilities/Net worth: Contingent Liability/Equity
# | X42 | Operating profit/Paid-in capital: Operating Income/Capital
# | X43 | Net profit before tax/Paid-in capital: Pretax Income/Capital
# | X44 | Inventory and accounts receivable/Net value: (Inventory+Accounts Receivables)/Equity
# | X45 | Total Asset Turnover
# | X46 | Accounts Receivable Turnover
# | X47 | Average Collection Days: Days Receivable Outstanding
# | X48 | Inventory Turnover Rate (times)
# | X49 | Fixed Assets Turnover Frequency
# | X50 | Net Worth Turnover Rate (times): Equity Turnover
# | X51 | Revenue per person: Sales Per Employee
# | X52 | Operating profit per person: Operation Income Per Employee
# | X53 | Allocation rate per person: Fixed Assets Per Employee
# | X54 | Working Capital to Total Assets
# | X55 | Quick Assets/Total Assets
# | X56 | Current Assets/Total Assets
# | X57 | Cash/Total Assets
# | X58 | Quick Assets/Current Liability
# | X59 | Cash/Current Liability
# | X60 | Current Liability to Assets
# | X61 | Operating Funds to Liability
# | X62 | Inventory/Working Capital
# | X63 | Inventory/Current Liability
# | X64 | Current Liabilities/Liability
# | X65 | Working Capital/Equity
# | X66 | Current Liabilities/Equity
# | X67 | Long-term Liability to Current Assets
# | X68 | Retained Earnings to Total Assets
# | X69 | Total income/Total expense
# | X70 | Total expense/Assets
# | X71 | Current Asset Turnover Rate: Current Assets to Sales
# | X72 | Quick Asset Turnover Rate: Quick Assets to Sales
# | X73 | Working capitcal Turnover Rate: Working Capital to Sales
# | X74 | Cash Turnover Rate: Cash to Sales
# | X75 | Cash Flow to Sales
# | X76 | Fixed Assets to Assets
# | X77 | Current Liability to Liability
# | X78 | Current Liability to Equity
# | X79 | Equity to Long-term Liability
# | X80 | Cash Flow to Total Assets
# | X81 | Cash Flow to Liability
# | X82 | CFO to Assets
# | X83 | Cash Flow to Equity
# | X84 | Current Liability to Current Assets
# | X85 | Liability-Assets Flag: 1 if Total Liability exceeds Total Assets, 0 otherwise
# | X86 | Net Income to Total Assets
# | X87 | Total assets to GNP price
# | X88 | No-credit Interval
# | X89 | Gross Profit to Sales
# | X90 | Net Income to Stockholder's Equity
# | X91 | Liability to Equity
# | X92 | Degree of Financial Leverage (DFL)
# | X93 | Interest Coverage Ratio (Interest expense to EBIT)
# | X94 | Net Income Flag: 1 if Net Income is Negative for the last two years, 0 otherwise
# | X95 | Equity to Liability

# %%
import pandas as pd
import numpy as np

# from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
import seaborn as sns

# %%
raw_df = pd.read_csv('data.csv') # Let's read the data
raw_df.head() # and see the first 5 rows
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.601457                      0.601457
# 1                 0.610235                      0.610235
# 2                 0.601450                      0.601364
# 3                 0.583541                      0.583541
# 4                 0.598783                      0.598783
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.998969                    0.796887
# 1                0.998946                    0.797380
# 2                0.998857                    0.796403
# 3                0.998700                    0.796967
# 4                0.998973                    0.797366
#
#     After-tax net Interest Rate   Non-industry income and expenditure/revenue  \
# 0                      0.808809                                      0.302646
# 1                      0.809301                                      0.303556
# 2                      0.808388                                      0.302035
# 3                      0.808966                                      0.303350
# 4                      0.809304                                      0.303475
#
#    ...   Net Income to Total Assets   Total assets to GNP price  \
# 0  ...                     0.716845                    0.009219
# 1  ...                     0.795297                    0.008323
# 2  ...                     0.774670                    0.040003
# 3  ...                     0.739555                    0.003252
# 4  ...                     0.795016                    0.003878
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.622879                0.601453
# 1             0.623652                0.610237
# 2             0.623841                0.601449
# 3             0.622929                0.583538
# 4             0.623521                0.598782
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.827890              0.290202
# 1                             0.839969              0.283846
# 2                             0.836774              0.290189
# 3                             0.834697              0.281721
# 4                             0.839973              0.278514
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026601
# 1                             0.264577
# 2                             0.026555
# 3                             0.026697
# 4                             0.024752
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.564050                   1
# 1                                           0.570175                   1
# 2                                           0.563706                   1
# 3                                           0.564663                   1
# 4                                           0.575617                   1
#
#     Equity to Liability
# 0              0.016469
# 1              0.020794
# 2              0.016474
# 3              0.023982
# 4              0.035490
#
# [5 rows x 96 columns]

# %%
raw_df.tail() # now the last 5 rows
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# 6817                                           0.554045
# 6818                                           0.549548
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 6814                 0.604455                      0.604462
# 6815                 0.598308                      0.598308
# 6816                 0.610444                      0.610213
# 6817                 0.607850                      0.607850
# 6818                 0.627409                      0.627409
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 6814                0.998992                    0.797409
# 6815                0.998992                    0.797414
# 6816                0.998984                    0.797401
# 6817                0.999074                    0.797500
# 6818                0.998080                    0.801987
#
#        After-tax net Interest Rate  \
# 6814                      0.809331
# 6815                      0.809327
# 6816                      0.809317
# 6817                      0.809399
# 6818                      0.813800
#
#        Non-industry income and expenditure/revenue  ...  \
# 6814                                      0.303510  ...
# 6815                                      0.303520  ...
# 6816                                      0.303512  ...
# 6817                                      0.303498  ...
# 6818                                      0.313415  ...
#
#        Net Income to Total Assets   Total assets to GNP price  \
# 6814                     0.799927                    0.000466
# 6815                     0.799748                    0.001959
# 6816                     0.797778                    0.002840
# 6817                     0.811808                    0.002837
# 6818                     0.815956                    0.000707
#
#        No-credit Interval   Gross Profit to Sales  \
# 6814             0.623620                0.604455
# 6815             0.623931                0.598306
# 6816             0.624156                0.610441
# 6817             0.623957                0.607846
# 6818             0.626680                0.627408
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 6814                             0.840359              0.279606
# 6815                             0.840306              0.278132
# 6816                             0.840138              0.275789
# 6817                             0.841084              0.277547
# 6818                             0.841019              0.275114
#
#        Degree of Financial Leverage (DFL)  \
# 6814                             0.027064
# 6815                             0.027009
# 6816                             0.026791
# 6817                             0.026822
# 6818                             0.026793
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 6814                                           0.566193                   1
# 6815                                           0.566018                   1
# 6816                                           0.565158                   1
# 6817                                           0.565302                   1
# 6818                                           0.565167                   1
#
#        Equity to Liability
# 6814              0.029890
# 6815              0.038284
# 6816              0.097649
# 6817              0.044009
# 6818              0.233902
#
# [5 rows x 96 columns]

# %%
print("The dimensions of the df are:", raw_df.shape) # Let's see how many rows and columns are there in the df
# Out:
# The dimensions of the df are: (6819, 96)

# %% [markdown]
# This means, that we have 6819 rows and 96 columns, let's see if there are any redundant/useless/null columns.

# %% [markdown]
# As we can see, all rows have non-null values in each column. Let's check for duplicates.

# %%
raw_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# As we can see there are no duplicate values. Let's see how many are unique for each column.

# %%
raw_df.nunique().sort_values()
# Out:
#  Net Income Flag                       1
# Bankrupt?                              2
#  Liability-Assets Flag                 2
#  Total Asset Turnover                381
#  Net Worth Turnover Rate (times)     741
#                                     ...
#  Current Liabilities/Equity         6819
#  Working Capital/Equity             6819
#  Operating Funds to Liability       6819
#  Cash Flow to Total Assets          6819
#  Equity to Liability                6819
# Length: 96, dtype: int64

# %% [markdown]
# As we can see, most columns have unique values for each row. Let's see some basic statistics for the columns.

# %%
raw_df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# 50%                                   0.559802
# 75%                                   0.589157
# max                                   1.000000
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        6819.000000
# mean                                            0.553589
# std                                             0.061595
# min                                             0.000000
# 25%                                             0.527277
# 50%                                             0.552278
# 75%                                             0.584105
# max                                             1.000000
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              6819.000000                   6819.000000
# mean                  0.607948                      0.607929
# std                   0.016934                      0.016916
# min                   0.000000                      0.000000
# 25%                   0.600445                      0.600434
# 50%                   0.605997                      0.605976
# 75%                   0.613914                      0.613842
# max                   1.000000                      1.000000
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             6819.000000                 6819.000000
# mean                 0.998755                    0.797190
# std                  0.013010                    0.012869
# min                  0.000000                    0.000000
# 25%                  0.998969                    0.797386
# 50%                  0.999022                    0.797464
# 75%                  0.999095                    0.797579
# max                  1.000000                    1.000000
#
#         After-tax net Interest Rate  \
# count                   6819.000000
# mean                       0.809084
# std                        0.013601
# min                        0.000000
# 25%                        0.809312
# 50%                        0.809375
# 75%                        0.809469
# max                        1.000000
#
#         Non-industry income and expenditure/revenue  ...  \
# count                                   6819.000000  ...
# mean                                       0.303623  ...
# std                                        0.011163  ...
# min                                        0.000000  ...
# 25%                                        0.303466  ...
# 50%                                        0.303525  ...
# 75%                                        0.303585  ...
# max                                        1.000000  ...
#
#         Net Income to Total Assets   Total assets to GNP price  \
# count                  6819.000000                6.819000e+03
# mean                      0.807760                1.862942e+07
# std                       0.040332                3.764501e+08
# min                       0.000000                0.000000e+00
# 25%                       0.796750                9.036205e-04
# 50%                       0.810619                2.085213e-03
# 75%                       0.826455                5.269777e-03
# max                       1.000000                9.820000e+09
#
#         No-credit Interval   Gross Profit to Sales  \
# count          6819.000000             6819.000000
# mean              0.623915                0.607946
# std               0.012290                0.016934
# min               0.000000                0.000000
# 25%               0.623636                0.600443
# 50%               0.623879                0.605998
# 75%               0.624168                0.613913
# max               1.000000                1.000000
#
#         Net Income to Stockholder's Equity   Liability to Equity  \
# count                          6819.000000           6819.000000
# mean                              0.840402              0.280365
# std                               0.014523              0.014463
# min                               0.000000              0.000000
# 25%                               0.840115              0.276944
# 50%                               0.841179              0.278778
# 75%                               0.842357              0.281449
# max                               1.000000              1.000000
#
#         Degree of Financial Leverage (DFL)  \
# count                          6819.000000
# mean                              0.027541
# std                               0.015668
# min                               0.000000
# 25%                               0.026791
# 50%                               0.026808
# 75%                               0.026913
# max                               1.000000
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        6819.000000              6819.0
# mean                                            0.565358                 1.0
# std                                             0.013214                 0.0
# min                                             0.000000                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565252                 1.0
# 75%                                             0.565725                 1.0
# max                                             1.000000                 1.0
#
#         Equity to Liability
# count           6819.000000
# mean               0.047578
# std                0.050014
# min                0.000000
# 25%                0.024477
# 50%                0.033798
# 75%                0.052838
# max                1.000000
#
# [8 rows x 96 columns]

# %%
sns.countplot(raw_df['Bankrupt?'])
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='Bankrupt?', ylabel='count'>

# %% [markdown]
# As we can see, not a lot of companies went bankrupt. Let's check a few other columns.

# %%
plt.figure(figsize=(100, 20))
sns.countplot(x=' Total Asset Turnover', data=raw_df)
# Out:
# <Axes: xlabel=' Total Asset Turnover', ylabel='count'>

# %%
raw_df.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
#        ' Realized Sales Gross Profit Growth Rate',
#        ' Operating Profit Growth Rate', ' After-tax Net Profit Growth Rate',
#        ' Regular Net Profit Growth Rate', ' Continuous Net Profit Growth Rate',
#        ' Total Asset Growth Rate', ' Net Value Growth Rate',
#        ' Total Asset Return Growth Rate Ratio', ' Cash Reinvestment %',
#        ' Current Ratio', ' Quick Ratio', ' Interest Expense Ratio',
#        ' Total debt/Total net worth', ' Debt ratio %', ' Net worth/Assets',
#        ' Long-term fund suitability ratio (A)', ' Borrowing dependency',
#        ' Contingent liabilities/Net worth',
#        ' Operating profit/Paid-in capital',
#        ' Net profit before tax/Paid-in capital',
#        ' Inventory and accounts receivable/Net value', ' Total Asset Turnover',
#        ' Accounts Receivable Turnover', ' Average Collection Days',
#        ' Inventory Turnover Rate (times)', ' Fixed Assets Turnover Frequency',
#        ' Net Worth Turnover Rate (times)', ' Revenue per person',
#        ' Operating profit per person', ' Allocation rate per person',
#        ' Working Capital to Total Assets', ' Quick Assets/Total Assets',
#        ' Current Assets/Total Assets', ' Cash/Total Assets',
#        ' Quick Assets/Current Liability', ' Cash/Current Liability',
#        ' Current Liability to Assets', ' Operating Funds to Liability',
#        ' Inventory/Working Capital', ' Inventory/Current Liability',
#        ' Current Liabilities/Liability', ' Working Capital/Equity',
#        ' Current Liabilities/Equity', ' Long-term Liability to Current Assets',
#        ' Retained Earnings to Total Assets', ' Total income/Total expense',
#        ' Total expense/Assets', ' Current Asset Turnover Rate',
#        ' Quick Asset Turnover Rate', ' Working capitcal Turnover Rate',
#        ' Cash Turnover Rate', ' Cash Flow to Sales', ' Fixed Assets to Assets',
#        ' Current Liability to Liability', ' Current Liability to Equity',
#        ' Equity to Long-term Liability', ' Cash Flow to Total Assets',
#        ' Cash Flow to Liability', ' CFO to Assets', ' Cash Flow to Equity',
#        ' Current Liability to Current Assets', ' Liability-Assets Flag',
#        ' Net Income to Total Assets', ' Total assets to GNP price',
#        ' No-credit Interval', ' Gross Profit to Sales',
#        ' Net Income to Stockholder's Equity', ' Liability to Equity',
#        ' Degree of Financial Leverage (DFL)',
#        ' Interest Coverage Ratio (Interest expense to EBIT)',
#        ' Net Income Flag', ' Equity to Liability'],
#       dtype='object')

# %%
target = raw_df.iloc[:, 0:1] # let's extract the target column - did the company go bankrupt
target
factors_df = raw_df.iloc[:, 1:] # and let's 
factors_df
# Out:
#        ROA(C) before interest and depreciation before interest  \
# 0                                              0.370594
# 1                                              0.464291
# 2                                              0.426071
# 3                                              0.399844
# 4                                              0.465022
# ...                                                 ...
# 6814                                           0.493687
# 6815                                           0.475162
# 6816                                           0.472725
# 6817                                           0.506264
# 6818                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...                                       ...
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 0                                              0.405750
# 1                                              0.516730
# 2                                              0.472295
# 3                                              0.457733
# 4                                              0.522298
# ...                                                 ...
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# 6817                                           0.554045
# 6818                                           0.549548
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 0                    0.601457                      0.601457
# 1                    0.610235                      0.610235
# 2                    0.601450                      0.601364
# 3                    0.583541                      0.583541
# 4                    0.598783                      0.598783
# ...                       ...                           ...
# 6814                 0.604455                      0.604462
# 6815                 0.598308                      0.598308
# 6816                 0.610444                      0.610213
# 6817                 0.607850                      0.607850
# 6818                 0.627409                      0.627409
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                   0.998969                    0.796887
# 1                   0.998946                    0.797380
# 2                   0.998857                    0.796403
# 3                   0.998700                    0.796967
# 4                   0.998973                    0.797366
# ...                      ...                         ...
# 6814                0.998992                    0.797409
# 6815                0.998992                    0.797414
# 6816                0.998984                    0.797401
# 6817                0.999074                    0.797500
# 6818                0.998080                    0.801987
#
#        After-tax net Interest Rate  \
# 0                         0.808809
# 1                         0.809301
# 2                         0.808388
# 3                         0.808966
# 4                         0.809304
# ...                            ...
# 6814                      0.809331
# 6815                      0.809327
# 6816                      0.809317
# 6817                      0.809399
# 6818                      0.813800
#
#        Non-industry income and expenditure/revenue  \
# 0                                         0.302646
# 1                                         0.303556
# 2                                         0.302035
# 3                                         0.303350
# 4                                         0.303475
# ...                                            ...
# 6814                                      0.303510
# 6815                                      0.303520
# 6816                                      0.303512
# 6817                                      0.303498
# 6818                                      0.313415
#
#        Continuous interest rate (after tax)  ...   Net Income to Total Assets  \
# 0                                  0.780985  ...                     0.716845
# 1                                  0.781506  ...                     0.795297
# 2                                  0.780284  ...                     0.774670
# 3                                  0.781241  ...                     0.739555
# 4                                  0.781550  ...                     0.795016
# ...                                     ...  ...                          ...
# 6814                               0.781588  ...                     0.799927
# 6815                               0.781586  ...                     0.799748
# 6816                               0.781546  ...                     0.797778
# 6817                               0.781663  ...                     0.811808
# 6818                               0.786079  ...                     0.815956
#
#        Total assets to GNP price   No-credit Interval   Gross Profit to Sales  \
# 0                       0.009219             0.622879                0.601453
# 1                       0.008323             0.623652                0.610237
# 2                       0.040003             0.623841                0.601449
# 3                       0.003252             0.622929                0.583538
# 4                       0.003878             0.623521                0.598782
# ...                          ...                  ...                     ...
# 6814                    0.000466             0.623620                0.604455
# 6815                    0.001959             0.623931                0.598306
# 6816                    0.002840             0.624156                0.610441
# 6817                    0.002837             0.623957                0.607846
# 6818                    0.000707             0.626680                0.627408
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 0                                0.827890              0.290202
# 1                                0.839969              0.283846
# 2                                0.836774              0.290189
# 3                                0.834697              0.281721
# 4                                0.839973              0.278514
# ...                                   ...                   ...
# 6814                             0.840359              0.279606
# 6815                             0.840306              0.278132
# 6816                             0.840138              0.275789
# 6817                             0.841084              0.277547
# 6818                             0.841019              0.275114
#
#        Degree of Financial Leverage (DFL)  \
# 0                                0.026601
# 1                                0.264577
# 2                                0.026555
# 3                                0.026697
# 4                                0.024752
# ...                                   ...
# 6814                             0.027064
# 6815                             0.027009
# 6816                             0.026791
# 6817                             0.026822
# 6818                             0.026793
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                              0.564050                   1
# 1                                              0.570175                   1
# 2                                              0.563706                   1
# 3                                              0.564663                   1
# 4                                              0.575617                   1
# ...                                                 ...                 ...
# 6814                                           0.566193                   1
# 6815                                           0.566018                   1
# 6816                                           0.565158                   1
# 6817                                           0.565302                   1
# 6818                                           0.565167                   1
#
#        Equity to Liability
# 0                 0.016469
# 1                 0.020794
# 2                 0.016474
# 3                 0.023982
# 4                 0.035490
# ...                    ...
# 6814              0.029890
# 6815              0.038284
# 6816              0.097649
# 6817              0.044009
# 6818              0.233902
#
# [6819 rows x 95 columns]

# %%
factors_df.hist(bins = 10, figsize=(40, 20))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming factors_df is your DataFrame
correlation_matrix = factors_df.corr()

# Create a heatmap plot
plt.figure(figsize=(50, 50))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Plot')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py:256: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# ## Dzięki tej macierzy łatwiej jest nam znaleźć zmienne które wydają się być zależne od siebie.

# %%
correlation_matrix_rounded = correlation_matrix.round(2)
correlation_matrix_rounded
# Out:
#                                                      ROA(C) before interest and depreciation before interest  \
#  ROA(C) before interest and depreciation before...                                               1.00
#  ROA(A) before interest and % after tax                                                          0.94
#  ROA(B) before interest and depreciation after tax                                               0.99
#  Operating Gross Margin                                                                          0.33
#  Realized Sales Gross Margin                                                                     0.33
# ...                                                                                               ...
#  Liability to Equity                                                                            -0.14
#  Degree of Financial Leverage (DFL)                                                             -0.02
#  Interest Coverage Ratio (Interest expense to E...                                               0.01
#  Net Income Flag                                                                                  NaN
#  Equity to Liability                                                                             0.05
#
#                                                      ROA(A) before interest and % after tax  \
#  ROA(C) before interest and depreciation before...                                     0.94
#  ROA(A) before interest and % after tax                                                1.00
#  ROA(B) before interest and depreciation after tax                                     0.96
#  Operating Gross Margin                                                                0.33
#  Realized Sales Gross Margin                                                           0.32
# ...                                                                                     ...
#  Liability to Equity                                                                  -0.14
#  Degree of Financial Leverage (DFL)                                                   -0.01
#  Interest Coverage Ratio (Interest expense to E...                                     0.01
#  Net Income Flag                                                                        NaN
#  Equity to Liability                                                                   0.06
#
#                                                      ROA(B) before interest and depreciation after tax  \
#  ROA(C) before interest and depreciation before...                                               0.99
#  ROA(A) before interest and % after tax                                                          0.96
#  ROA(B) before interest and depreciation after tax                                               1.00
#  Operating Gross Margin                                                                          0.33
#  Realized Sales Gross Margin                                                                     0.33
# ...                                                                                               ...
#  Liability to Equity                                                                            -0.14
#  Degree of Financial Leverage (DFL)                                                             -0.01
#  Interest Coverage Ratio (Interest expense to E...                                               0.01
#  Net Income Flag                                                                                  NaN
#  Equity to Liability                                                                             0.06
#
#                                                      Operating Gross Margin  \
#  ROA(C) before interest and depreciation before...                     0.33
#  ROA(A) before interest and % after tax                                0.33
#  ROA(B) before interest and depreciation after tax                     0.33
#  Operating Gross Margin                                                1.00
#  Realized Sales Gross Margin                                           1.00
# ...                                                                     ...
#  Liability to Equity                                                  -0.09
#  Degree of Financial Leverage (DFL)                                   -0.01
#  Interest Coverage Ratio (Interest expense to E...                    -0.00
#  Net Income Flag                                                        NaN
#  Equity to Liability                                                   0.12
#
#                                                      Realized Sales Gross Margin  \
#  ROA(C) before interest and depreciation before...                          0.33
#  ROA(A) before interest and % after tax                                     0.32
#  ROA(B) before interest and depreciation after tax                          0.33
#  Operating Gross Margin                                                     1.00
#  Realized Sales Gross Margin                                                1.00
# ...                                                                          ...
#  Liability to Equity                                                       -0.09
#  Degree of Financial Leverage (DFL)                                        -0.01
#  Interest Coverage Ratio (Interest expense to E...                         -0.00
#  Net Income Flag                                                             NaN
#  Equity to Liability                                                        0.12
#
#                                                      Operating Profit Rate  \
#  ROA(C) before interest and depreciation before...                    0.04
#  ROA(A) before interest and % after tax                               0.03
#  ROA(B) before interest and depreciation after tax                    0.04
#  Operating Gross Margin                                               0.01
#  Realized Sales Gross Margin                                          0.01
# ...                                                                    ...
#  Liability to Equity                                                  0.00
#  Degree of Financial Leverage (DFL)                                   0.00
#  Interest Coverage Ratio (Interest expense to E...                    0.00
#  Net Income Flag                                                       NaN
#  Equity to Liability                                                 -0.02
#
#                                                      Pre-tax net Interest Rate  \
#  ROA(C) before interest and depreciation before...                        0.05
#  ROA(A) before interest and % after tax                                   0.05
#  ROA(B) before interest and depreciation after tax                        0.05
#  Operating Gross Margin                                                   0.03
#  Realized Sales Gross Margin                                              0.03
# ...                                                                        ...
#  Liability to Equity                                                     -0.00
#  Degree of Financial Leverage (DFL)                                       0.00
#  Interest Coverage Ratio (Interest expense to E...                        0.00
#  Net Income Flag                                                           NaN
#  Equity to Liability                                                     -0.01
#
#                                                      After-tax net Interest Rate  \
#  ROA(C) before interest and depreciation before...                          0.05
#  ROA(A) before interest and % after tax                                     0.05
#  ROA(B) before interest and depreciation after tax                          0.05
#  Operating Gross Margin                                                     0.03
#  Realized Sales Gross Margin                                                0.03
# ...                                                                          ...
#  Liability to Equity                                                       -0.00
#  Degree of Financial Leverage (DFL)                                         0.00
#  Interest Coverage Ratio (Interest expense to E...                          0.00
#  Net Income Flag                                                             NaN
#  Equity to Liability                                                       -0.01
#
#                                                      Non-industry income and expenditure/revenue  \
#  ROA(C) before interest and depreciation before...                                          0.02
#  ROA(A) before interest and % after tax                                                     0.03
#  ROA(B) before interest and depreciation after tax                                          0.02
#  Operating Gross Margin                                                                     0.05
#  Realized Sales Gross Margin                                                                0.05
# ...                                                                                          ...
#  Liability to Equity                                                                       -0.01
#  Degree of Financial Leverage (DFL)                                                        -0.00
#  Interest Coverage Ratio (Interest expense to E...                                          0.00
#  Net Income Flag                                                                             NaN
#  Equity to Liability                                                                        0.01
#
#                                                      Continuous interest rate (after tax)  \
#  ROA(C) before interest and depreciation before...                                   0.05
#  ROA(A) before interest and % after tax                                              0.05
#  ROA(B) before interest and depreciation after tax                                   0.05
#  Operating Gross Margin                                                              0.03
#  Realized Sales Gross Margin                                                         0.03
# ...                                                                                   ...
#  Liability to Equity                                                                -0.00
#  Degree of Financial Leverage (DFL)                                                  0.00
#  Interest Coverage Ratio (Interest expense to E...                                   0.00
#  Net Income Flag                                                                      NaN
#  Equity to Liability                                                                -0.01
#
#                                                     ...  \
#  ROA(C) before interest and depreciation before...  ...
#  ROA(A) before interest and % after tax             ...
#  ROA(B) before interest and depreciation after tax  ...
#  Operating Gross Margin                             ...
#  Realized Sales Gross Margin                        ...
# ...                                                 ...
#  Liability to Equity                                ...
#  Degree of Financial Leverage (DFL)                 ...
#  Interest Coverage Ratio (Interest expense to E...  ...
#  Net Income Flag                                    ...
#  Equity to Liability                                ...
#
#                                                      Net Income to Total Assets  \
#  ROA(C) before interest and depreciation before...                         0.89
#  ROA(A) before interest and % after tax                                    0.96
#  ROA(B) before interest and depreciation after tax                         0.91
#  Operating Gross Margin                                                    0.30
#  Realized Sales Gross Margin                                               0.30
# ...                                                                         ...
#  Liability to Equity                                                      -0.16
#  Degree of Financial Leverage (DFL)                                       -0.01
#  Interest Coverage Ratio (Interest expense to E...                         0.01
#  Net Income Flag                                                            NaN
#  Equity to Liability                                                       0.07
#
#                                                      Total assets to GNP price  \
#  ROA(C) before interest and depreciation before...                       -0.07
#  ROA(A) before interest and % after tax                                  -0.10
#  ROA(B) before interest and depreciation after tax                       -0.09
#  Operating Gross Margin                                                   0.02
#  Realized Sales Gross Margin                                              0.02
# ...                                                                        ...
#  Liability to Equity                                                      0.02
#  Degree of Financial Leverage (DFL)                                      -0.00
#  Interest Coverage Ratio (Interest expense to E...                        0.00
#  Net Income Flag                                                           NaN
#  Equity to Liability                                                      0.01
#
#                                                      No-credit Interval  \
#  ROA(C) before interest and depreciation before...                 0.01
#  ROA(A) before interest and % after tax                            0.01
#  ROA(B) before interest and depreciation after tax                 0.01
#  Operating Gross Margin                                            0.00
#  Realized Sales Gross Margin                                       0.00
# ...                                                                 ...
#  Liability to Equity                                              -0.00
#  Degree of Financial Leverage (DFL)                               -0.01
#  Interest Coverage Ratio (Interest expense to E...                 0.00
#  Net Income Flag                                                    NaN
#  Equity to Liability                                               0.05
#
#                                                      Gross Profit to Sales  \
#  ROA(C) before interest and depreciation before...                    0.33
#  ROA(A) before interest and % after tax                               0.33
#  ROA(B) before interest and depreciation after tax                    0.33
#  Operating Gross Margin                                               1.00
#  Realized Sales Gross Margin                                          1.00
# ...                                                                    ...
#  Liability to Equity                                                 -0.09
#  Degree of Financial Leverage (DFL)                                  -0.01
#  Interest Coverage Ratio (Interest expense to E...                   -0.00
#  Net Income Flag                                                       NaN
#  Equity to Liability                                                  0.12
#
#                                                      Net Income to Stockholder's Equity  \
#  ROA(C) before interest and depreciation before...                                 0.27
#  ROA(A) before interest and % after tax                                            0.29
#  ROA(B) before interest and depreciation after tax                                 0.28
#  Operating Gross Margin                                                            0.08
#  Realized Sales Gross Margin                                                       0.07
# ...                                                                                 ...
#  Liability to Equity                                                              -0.79
#  Degree of Financial Leverage (DFL)                                               -0.00
#  Interest Coverage Ratio (Interest expense to E...                                 0.01
#  Net Income Flag                                                                    NaN
#  Equity to Liability                                                               0.03
#
#                                                      Liability to Equity  \
#  ROA(C) before interest and depreciation before...                 -0.14
#  ROA(A) before interest and % after tax                            -0.14
#  ROA(B) before interest and depreciation after tax                 -0.14
#  Operating Gross Margin                                            -0.09
#  Realized Sales Gross Margin                                       -0.09
# ...                                                                  ...
#  Liability to Equity                                                1.00
#  Degree of Financial Leverage (DFL)                                 0.00
#  Interest Coverage Ratio (Interest expense to E...                  0.00
#  Net Income Flag                                                     NaN
#  Equity to Liability                                               -0.16
#
#                                                      Degree of Financial Leverage (DFL)  \
#  ROA(C) before interest and depreciation before...                                -0.02
#  ROA(A) before interest and % after tax                                           -0.01
#  ROA(B) before interest and depreciation after tax                                -0.01
#  Operating Gross Margin                                                           -0.01
#  Realized Sales Gross Margin                                                      -0.01
# ...                                                                                 ...
#  Liability to Equity                                                               0.00
#  Degree of Financial Leverage (DFL)                                                1.00
#  Interest Coverage Ratio (Interest expense to E...                                 0.02
#  Net Income Flag                                                                    NaN
#  Equity to Liability                                                              -0.02
#
#                                                      Interest Coverage Ratio (Interest expense to EBIT)  \
#  ROA(C) before interest and depreciation before...                                               0.01
#  ROA(A) before interest and % after tax                                                          0.01
#  ROA(B) before interest and depreciation after tax                                               0.01
#  Operating Gross Margin                                                                         -0.00
#  Realized Sales Gross Margin                                                                    -0.00
# ...                                                                                               ...
#  Liability to Equity                                                                             0.00
#  Degree of Financial Leverage (DFL)                                                              0.02
#  Interest Coverage Ratio (Interest expense to E...                                               1.00
#  Net Income Flag                                                                                  NaN
#  Equity to Liability                                                                            -0.01
#
#                                                      Net Income Flag  \
#  ROA(C) before interest and depreciation before...               NaN
#  ROA(A) before interest and % after tax                          NaN
#  ROA(B) before interest and depreciation after tax               NaN
#  Operating Gross Margin                                          NaN
#  Realized Sales Gross Margin                                     NaN
# ...                                                              ...
#  Liability to Equity                                             NaN
#  Degree of Financial Leverage (DFL)                              NaN
#  Interest Coverage Ratio (Interest expense to E...               NaN
#  Net Income Flag                                                 NaN
#  Equity to Liability                                             NaN
#
#                                                      Equity to Liability
#  ROA(C) before interest and depreciation before...                  0.05
#  ROA(A) before interest and % after tax                             0.06
#  ROA(B) before interest and depreciation after tax                  0.06
#  Operating Gross Margin                                             0.12
#  Realized Sales Gross Margin                                        0.12
# ...                                                                  ...
#  Liability to Equity                                               -0.16
#  Degree of Financial Leverage (DFL)                                -0.02
#  Interest Coverage Ratio (Interest expense to E...                 -0.01
#  Net Income Flag                                                     NaN
#  Equity to Liability                                                1.00
#
# [95 rows x 95 columns]

# %%
sns.pairplot(factors_df, y_vars=factors_df.columns.values[1:2], x_vars=factors_df.columns.values[:5])

# %%
# Find pairs with absolute correlation value over 0.5
high_correlation_pairs = {}
for i in range(len(correlation_matrix_rounded.columns)):
    for j in range(i+1, len(correlation_matrix_rounded.columns)):
        pair = (correlation_matrix_rounded.columns[i], correlation_matrix_rounded.columns[j])
        correlation_value = correlation_matrix_rounded.iloc[i, j]
        if abs(correlation_value) > 0.5:
            high_correlation_pairs[pair] = correlation_value

# Print pairs with their correlation value
for pair, correlation_value in high_correlation_pairs.items():
    print(f"Pair: {pair}, Correlation Value: {correlation_value}")
# Out:
# Pair: (' ROA(C) before interest and depreciation before interest', ' ROA(A) before interest and % after tax'), Correlation Value: 0.94
# Pair: (' ROA(C) before interest and depreciation before interest', ' ROA(B) before interest and depreciation after tax'), Correlation Value: 0.99
# Pair: (' ROA(C) before interest and depreciation before interest', ' Net Value Per Share (B)'), Correlation Value: 0.51
# Pair: (' ROA(C) before interest and depreciation before interest', ' Net Value Per Share (A)'), Correlation Value: 0.51
# Pair: (' ROA(C) before interest and depreciation before interest', ' Net Value Per Share (C)'), Correlation Value: 0.51
# Pair: (' ROA(C) before interest and depreciation before interest', ' Persistent EPS in the Last Four Seasons'), Correlation Value: 0.78
# Pair: (' ROA(C) before interest and depreciation before interest', ' Operating Profit Per Share (Yuan ¥)'), Correlation Value: 0.69
# Pair: (' ROA(C) before interest and depreciation before interest', ' Per Share Net profit before tax (Yuan ¥)'), Correlation Value: 0.75
# Pair: (' ROA(C) before interest and depreciation before interest', ' Operating profit/Paid-in capital'), Correlation Value: 0.69
# Pair: (' ROA(C) before interest and depreciation before interest', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.75
# Pair: (' ROA(C) before interest and depreciation before interest', ' Retained Earnings to Total Assets'), Correlation Value: 0.65
# Pair: (' ROA(C) before interest and depreciation before interest', ' Net Income to Total Assets'), Correlation Value: 0.89
# Pair: (' ROA(A) before interest and % after tax', ' ROA(B) before interest and depreciation after tax'), Correlation Value: 0.96
# Pair: (' ROA(A) before interest and % after tax', ' Net Value Per Share (B)'), Correlation Value: 0.53
# Pair: (' ROA(A) before interest and % after tax', ' Net Value Per Share (A)'), Correlation Value: 0.53
# Pair: (' ROA(A) before interest and % after tax', ' Net Value Per Share (C)'), Correlation Value: 0.53
# Pair: (' ROA(A) before interest and % after tax', ' Persistent EPS in the Last Four Seasons'), Correlation Value: 0.76
# Pair: (' ROA(A) before interest and % after tax', ' Operating Profit Per Share (Yuan ¥)'), Correlation Value: 0.65
# Pair: (' ROA(A) before interest and % after tax', ' Per Share Net profit before tax (Yuan ¥)'), Correlation Value: 0.75
# Pair: (' ROA(A) before interest and % after tax', ' Operating profit/Paid-in capital'), Correlation Value: 0.65
# Pair: (' ROA(A) before interest and % after tax', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.76
# Pair: (' ROA(A) before interest and % after tax', ' Retained Earnings to Total Assets'), Correlation Value: 0.72
# Pair: (' ROA(A) before interest and % after tax', ' Net Income to Total Assets'), Correlation Value: 0.96
# Pair: (' ROA(B) before interest and depreciation after tax', ' Persistent EPS in the Last Four Seasons'), Correlation Value: 0.76
# Pair: (' ROA(B) before interest and depreciation after tax', ' Operating Profit Per Share (Yuan ¥)'), Correlation Value: 0.66
# Pair: (' ROA(B) before interest and depreciation after tax', ' Per Share Net profit before tax (Yuan ¥)'), Correlation Value: 0.72
# Pair: (' ROA(B) before interest and depreciation after tax', ' Operating profit/Paid-in capital'), Correlation Value: 0.66
# Pair: (' ROA(B) before interest and depreciation after tax', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.73
# Pair: (' ROA(B) before interest and depreciation after tax', ' Retained Earnings to Total Assets'), Correlation Value: 0.67
# Pair: (' ROA(B) before interest and depreciation after tax', ' Net Income to Total Assets'), Correlation Value: 0.91
# Pair: (' Operating Gross Margin', ' Realized Sales Gross Margin'), Correlation Value: 1.0
# Pair: (' Operating Gross Margin', ' Gross Profit to Sales'), Correlation Value: 1.0
# Pair: (' Realized Sales Gross Margin', ' Gross Profit to Sales'), Correlation Value: 1.0
# Pair: (' Operating Profit Rate', ' Pre-tax net Interest Rate'), Correlation Value: 0.92
# Pair: (' Operating Profit Rate', ' After-tax net Interest Rate'), Correlation Value: 0.86
# Pair: (' Operating Profit Rate', ' Non-industry income and expenditure/revenue'), Correlation Value: -0.59
# Pair: (' Operating Profit Rate', ' Continuous interest rate (after tax)'), Correlation Value: 0.92
# Pair: (' Pre-tax net Interest Rate', ' After-tax net Interest Rate'), Correlation Value: 0.99
# Pair: (' Pre-tax net Interest Rate', ' Continuous interest rate (after tax)'), Correlation Value: 0.99
# Pair: (' After-tax net Interest Rate', ' Continuous interest rate (after tax)'), Correlation Value: 0.98
# Pair: (' Non-industry income and expenditure/revenue', ' Working capitcal Turnover Rate'), Correlation Value: 0.74
# Pair: (' Non-industry income and expenditure/revenue', ' Cash Flow to Sales'), Correlation Value: 0.68
# Pair: (' Cash flow rate', ' Operating Funds to Liability'), Correlation Value: 0.88
# Pair: (' Cash flow rate', ' CFO to Assets'), Correlation Value: 0.6
# Pair: (' Net Value Per Share (B)', ' Net Value Per Share (A)'), Correlation Value: 1.0
# Pair: (' Net Value Per Share (B)', ' Net Value Per Share (C)'), Correlation Value: 1.0
# Pair: (' Net Value Per Share (B)', ' Persistent EPS in the Last Four Seasons'), Correlation Value: 0.76
# Pair: (' Net Value Per Share (B)', ' Operating Profit Per Share (Yuan ¥)'), Correlation Value: 0.61
# Pair: (' Net Value Per Share (B)', ' Per Share Net profit before tax (Yuan ¥)'), Correlation Value: 0.73
# Pair: (' Net Value Per Share (B)', ' Operating profit/Paid-in capital'), Correlation Value: 0.6
# Pair: (' Net Value Per Share (B)', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.71
# Pair: (' Net Value Per Share (A)', ' Net Value Per Share (C)'), Correlation Value: 1.0
# Pair: (' Net Value Per Share (A)', ' Persistent EPS in the Last Four Seasons'), Correlation Value: 0.76
# Pair: (' Net Value Per Share (A)', ' Operating Profit Per Share (Yuan ¥)'), Correlation Value: 0.61
# Pair: (' Net Value Per Share (A)', ' Per Share Net profit before tax (Yuan ¥)'), Correlation Value: 0.73
# Pair: (' Net Value Per Share (A)', ' Operating profit/Paid-in capital'), Correlation Value: 0.6
# Pair: (' Net Value Per Share (A)', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.71
# Pair: (' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons'), Correlation Value: 0.76
# Pair: (' Net Value Per Share (C)', ' Operating Profit Per Share (Yuan ¥)'), Correlation Value: 0.61
# Pair: (' Net Value Per Share (C)', ' Per Share Net profit before tax (Yuan ¥)'), Correlation Value: 0.73
# Pair: (' Net Value Per Share (C)', ' Operating profit/Paid-in capital'), Correlation Value: 0.6
# Pair: (' Net Value Per Share (C)', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.71
# Pair: (' Persistent EPS in the Last Four Seasons', ' Operating Profit Per Share (Yuan ¥)'), Correlation Value: 0.88
# Pair: (' Persistent EPS in the Last Four Seasons', ' Per Share Net profit before tax (Yuan ¥)'), Correlation Value: 0.96
# Pair: (' Persistent EPS in the Last Four Seasons', ' Operating profit/Paid-in capital'), Correlation Value: 0.87
# Pair: (' Persistent EPS in the Last Four Seasons', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.96
# Pair: (' Persistent EPS in the Last Four Seasons', ' Net Income to Total Assets'), Correlation Value: 0.69
# Pair: (' Cash Flow Per Share', ' Cash Reinvestment %'), Correlation Value: 0.65
# Pair: (' Cash Flow Per Share', ' CFO to Assets'), Correlation Value: 0.72
# Pair: (' Operating Profit Per Share (Yuan ¥)', ' Per Share Net profit before tax (Yuan ¥)'), Correlation Value: 0.86
# Pair: (' Operating Profit Per Share (Yuan ¥)', ' Operating profit/Paid-in capital'), Correlation Value: 1.0
# Pair: (' Operating Profit Per Share (Yuan ¥)', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.89
# Pair: (' Operating Profit Per Share (Yuan ¥)', ' Net Income to Total Assets'), Correlation Value: 0.58
# Pair: (' Per Share Net profit before tax (Yuan ¥)', ' Operating profit/Paid-in capital'), Correlation Value: 0.86
# Pair: (' Per Share Net profit before tax (Yuan ¥)', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.96
# Pair: (' Per Share Net profit before tax (Yuan ¥)', ' Net Income to Total Assets'), Correlation Value: 0.67
# Pair: (' Operating Profit Growth Rate', ' After-tax Net Profit Growth Rate'), Correlation Value: 0.64
# Pair: (' Operating Profit Growth Rate', ' Regular Net Profit Growth Rate'), Correlation Value: 0.64
# Pair: (' After-tax Net Profit Growth Rate', ' Regular Net Profit Growth Rate'), Correlation Value: 1.0
# Pair: (' Cash Reinvestment %', ' CFO to Assets'), Correlation Value: 0.74
# Pair: (' Debt ratio %', ' Net worth/Assets'), Correlation Value: -1.0
# Pair: (' Debt ratio %', ' Working Capital to Total Assets'), Correlation Value: -0.53
# Pair: (' Debt ratio %', ' Current Liability to Assets'), Correlation Value: 0.84
# Pair: (' Debt ratio %', ' Equity to Liability'), Correlation Value: -0.63
# Pair: (' Net worth/Assets', ' Working Capital to Total Assets'), Correlation Value: 0.53
# Pair: (' Net worth/Assets', ' Current Liability to Assets'), Correlation Value: -0.84
# Pair: (' Net worth/Assets', ' Equity to Liability'), Correlation Value: 0.63
# Pair: (' Borrowing dependency', ' Inventory and accounts receivable/Net value'), Correlation Value: 0.7
# Pair: (' Borrowing dependency', ' Working Capital/Equity'), Correlation Value: -0.54
# Pair: (' Borrowing dependency', ' Current Liabilities/Equity'), Correlation Value: 0.89
# Pair: (' Borrowing dependency', ' Current Liability to Equity'), Correlation Value: 0.89
# Pair: (' Borrowing dependency', ' Equity to Long-term Liability'), Correlation Value: 0.81
# Pair: (' Borrowing dependency', " Net Income to Stockholder's Equity"), Correlation Value: -0.81
# Pair: (' Borrowing dependency', ' Liability to Equity'), Correlation Value: 0.96
# Pair: (' Contingent liabilities/Net worth', ' Working Capital/Equity'), Correlation Value: -0.77
# Pair: (' Contingent liabilities/Net worth', ' Current Liabilities/Equity'), Correlation Value: 0.62
# Pair: (' Contingent liabilities/Net worth', ' Current Liability to Equity'), Correlation Value: 0.62
# Pair: (' Contingent liabilities/Net worth', ' Liability to Equity'), Correlation Value: 0.62
# Pair: (' Operating profit/Paid-in capital', ' Net profit before tax/Paid-in capital'), Correlation Value: 0.89
# Pair: (' Operating profit/Paid-in capital', ' Net Income to Total Assets'), Correlation Value: 0.58
# Pair: (' Net profit before tax/Paid-in capital', ' Net Income to Total Assets'), Correlation Value: 0.68
# Pair: (' Inventory and accounts receivable/Net value', ' Current Liabilities/Equity'), Correlation Value: 0.66
# Pair: (' Inventory and accounts receivable/Net value', ' Current Liability to Equity'), Correlation Value: 0.66
# Pair: (' Inventory and accounts receivable/Net value', ' Liability to Equity'), Correlation Value: 0.67
# Pair: (' Total Asset Turnover', ' Net Worth Turnover Rate (times)'), Correlation Value: 0.76
# Pair: (' Working Capital to Total Assets', ' Quick Assets/Total Assets'), Correlation Value: 0.65
# Pair: (' Working Capital to Total Assets', ' Current Assets/Total Assets'), Correlation Value: 0.71
# Pair: (' Working Capital to Total Assets', ' Cash/Total Assets'), Correlation Value: 0.59
# Pair: (' Working Capital to Total Assets', ' Current Liability to Current Assets'), Correlation Value: -0.63
# Pair: (' Quick Assets/Total Assets', ' Current Assets/Total Assets'), Correlation Value: 0.76
# Pair: (' Quick Assets/Total Assets', ' Cash/Total Assets'), Correlation Value: 0.59
# Pair: (' Current Assets/Total Assets', ' Current Liabilities/Liability'), Correlation Value: 0.57
# Pair: (' Current Assets/Total Assets', ' Current Liability to Liability'), Correlation Value: 0.57
# Pair: (' Current Liability to Assets', ' Equity to Liability'), Correlation Value: -0.51
# Pair: (' Operating Funds to Liability', ' CFO to Assets'), Correlation Value: 0.7
# Pair: (' Current Liabilities/Liability', ' Current Liability to Liability'), Correlation Value: 1.0
# Pair: (' Working Capital/Equity', ' Current Liabilities/Equity'), Correlation Value: -0.69
# Pair: (' Working Capital/Equity', ' Current Liability to Equity'), Correlation Value: -0.69
# Pair: (' Working Capital/Equity', " Net Income to Stockholder's Equity"), Correlation Value: 0.59
# Pair: (' Working Capital/Equity', ' Liability to Equity'), Correlation Value: -0.65
# Pair: (' Current Liabilities/Equity', ' Current Liability to Equity'), Correlation Value: 1.0
# Pair: (' Current Liabilities/Equity', ' Equity to Long-term Liability'), Correlation Value: 0.59
# Pair: (' Current Liabilities/Equity', " Net Income to Stockholder's Equity"), Correlation Value: -0.75
# Pair: (' Current Liabilities/Equity', ' Liability to Equity'), Correlation Value: 0.96
# Pair: (' Retained Earnings to Total Assets', ' Total expense/Assets'), Correlation Value: -0.54
# Pair: (' Retained Earnings to Total Assets', ' Net Income to Total Assets'), Correlation Value: 0.79
# Pair: (' Working capitcal Turnover Rate', ' Cash Flow to Sales'), Correlation Value: 0.95
# Pair: (' Current Liability to Equity', ' Equity to Long-term Liability'), Correlation Value: 0.59
# Pair: (' Current Liability to Equity', " Net Income to Stockholder's Equity"), Correlation Value: -0.75
# Pair: (' Current Liability to Equity', ' Liability to Equity'), Correlation Value: 0.96
# Pair: (' Equity to Long-term Liability', " Net Income to Stockholder's Equity"), Correlation Value: -0.62
# Pair: (' Equity to Long-term Liability', ' Liability to Equity'), Correlation Value: 0.78
# Pair: (' Cash Flow to Total Assets', ' Cash Flow to Liability'), Correlation Value: 0.71
# Pair: (' Cash Flow to Total Assets', ' Cash Flow to Equity'), Correlation Value: 0.59
# Pair: (" Net Income to Stockholder's Equity", ' Liability to Equity'), Correlation Value: -0.79

# %%
sns.heatmap(factors_df.corr())
# Out:
# <Axes: >
